# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from pandas import DataFrame

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("charity_data.csv")
application_df.head()
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Find 'ASK_AMT' outliers
Q1 = np.percentile(application_df['ASK_AMT'], 25)
# 3st quartile
Q3 = np.percentile(application_df['ASK_AMT'], 75)
# IQR
IQR = Q3 - Q1
# Outlier Step
outlier_step = IQR * 1.5
low_outlier_step = Q1 - outlier_step
high_outlier_step = Q3 + outlier_step

# %%
# Add an 'Outlier' column
application_df['Outlier'] = np.where((application_df['ASK_AMT']< low_outlier_step) | (application_df['ASK_AMT']> high_outlier_step), 1 , 0)
application_df
# Out:
#              EIN                                               NAME  \
# 0       10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1       10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2       10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3       10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4       10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# ...          ...                                                ...
# 34294  996009318              THE LIONS CLUB OF HONOLULU KAMEHAMEHA
# 34295  996010315           INTERNATIONAL ASSOCIATION OF LIONS CLUBS
# 34296  996012607                                PTA HAWAII CONGRESS
# 34297  996015768  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...
# 34298  996086871                           WATERHOUSE CHARITABLE TR
#
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL  Outlier
# 0                  1        0
# 1                  1        1
# 2                  0        0
# 3                  1        0
# 4                  1        1
# ...              ...      ...
# 34294              0        0
# 34295              0        0
# 34296              0        0
# 34297              1        0
# 34298              0        1
#
# [34299 rows x 13 columns]

# %%
# Drop rows based on previously calculated feature importance and 'ASK_AMT' outliers 
index_names = application_df[((application_df['CLASSIFICATION'] == 'C2000') |(application_df['CLASSIFICATION'] == 'C1000')
                              |(application_df['CLASSIFICATION'] == 'C1200') |(application_df['CLASSIFICATION'] == 'C1700')|(application_df['CLASSIFICATION'] == 'C5000')
                              |(application_df['CLASSIFICATION'] == 'C3000')
                              | (application_df['CLASSIFICATION'] == 'C2100')) & 
                            application_df['Outlier']== 1].index
#index_names
application_df.drop(index_names, inplace = True)

# %%
# Select columns to be be used as features based on previously calculated feature importance
newdf = application_df[['ASK_AMT', 'AFFILIATION', 'ORGANIZATION', "APPLICATION_TYPE", "CLASSIFICATION","INCOME_AMT", "USE_CASE", "Outlier", "IS_SUCCESSFUL" ]]
newdf_ = DataFrame(newdf, columns=['ASK_AMT', 'AFFILIATION', 'ORGANIZATION', "APPLICATION_TYPE", "CLASSIFICATION", "INCOME_AMT", "USE_CASE", "Outlier", "IS_SUCCESSFUL"])
newdf_
# Out:
#        ASK_AMT       AFFILIATION ORGANIZATION APPLICATION_TYPE CLASSIFICATION  \
# 0         5000       Independent  Association              T10          C1000
# 2         5000  CompanySponsored  Association               T5          C3000
# 3         6692  CompanySponsored        Trust               T3          C2000
# 5         5000       Independent        Trust               T3          C1200
# 9         5000  CompanySponsored  Association               T5          C3000
# ...        ...               ...          ...              ...            ...
# 34293     5000  CompanySponsored  Association               T3          C1000
# 34294     5000       Independent  Association               T4          C1000
# 34295     5000  CompanySponsored  Association               T4          C3000
# 34296     5000  CompanySponsored  Association               T3          C2000
# 34297     5000       Independent  Association               T5          C3000
#
#         INCOME_AMT      USE_CASE  Outlier  IS_SUCCESSFUL
# 0                0    ProductDev        0              1
# 2                0    ProductDev        0              0
# 3      10000-24999  Preservation        0              1
# 5                0  Preservation        0              1
# 9                0    ProductDev        0              0
# ...            ...           ...      ...            ...
# 34293            0  Preservation        0              1
# 34294            0    ProductDev        0              0
# 34295            0    ProductDev        0              0
# 34296            0  Preservation        0              0
# 34297            0    ProductDev        0              1
#
# [26594 rows x 9 columns]

# %%
newdf__dtypes = pd.DataFrame(newdf_.dtypes)

# %%
newdf__dtypes.index = newdf__dtypes.index.set_names(['Column_Name'])
newdf__dtypes.rename(columns = {0: "Data_Type"}, inplace=True)
newdf__dtypes.reset_index()
# Out:
#         Column_Name Data_Type
# 0           ASK_AMT     int64
# 1       AFFILIATION    object
# 2      ORGANIZATION    object
# 3  APPLICATION_TYPE    object
# 4    CLASSIFICATION    object
# 5        INCOME_AMT    object
# 6          USE_CASE    object
# 7           Outlier     int32
# 8     IS_SUCCESSFUL     int64

# %%
df_string = newdf__dtypes[newdf__dtypes['Data_Type']=='object']
df_string
# Out:
#                  Data_Type
# Column_Name
# AFFILIATION         object
# ORGANIZATION        object
# APPLICATION_TYPE    object
# CLASSIFICATION      object
# INCOME_AMT          object
# USE_CASE            object

# %%
# Create the training variables by converting the string values into numerical ones using the get_dummies() method.
newdf_ = pd.get_dummies(newdf_, columns=["AFFILIATION", "ORGANIZATION", "APPLICATION_TYPE", "CLASSIFICATION", "INCOME_AMT", "USE_CASE"])
newdf_.head()
# Out:
#    ASK_AMT  Outlier  IS_SUCCESSFUL  AFFILIATION_CompanySponsored  \
# 0     5000        0              1                             0
# 2     5000        0              0                             1
# 3     6692        0              1                             1
# 5     5000        0              1                             0
# 9     5000        0              0                             1
#
#    AFFILIATION_Family/Parent  AFFILIATION_Independent  AFFILIATION_National  \
# 0                          0                        1                     0
# 2                          0                        0                     0
# 3                          0                        0                     0
# 5                          0                        1                     0
# 9                          0                        0                     0
#
#    AFFILIATION_Other  AFFILIATION_Regional  ORGANIZATION_Association  ...  \
# 0                  0                     0                         1  ...
# 2                  0                     0                         1  ...
# 3                  0                     0                         0  ...
# 5                  0                     0                         0  ...
# 9                  0                     0                         1  ...
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                   0                 0                       0
# 2                   0                 0                       0
# 3                   0                 0                       0
# 5                   0                 0                       0
# 9                   0                 0                       0
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  USE_CASE_CommunityServ  \
# 0                0                  0                       0
# 2                0                  0                       0
# 3                0                  0                       0
# 5                0                  0                       0
# 9                0                  0                       0
#
#    USE_CASE_Heathcare  USE_CASE_Other  USE_CASE_Preservation  \
# 0                   0               0                      0
# 2                   0               0                      0
# 3                   0               0                      1
# 5                   0               0                      1
# 9                   0               0                      0
#
#    USE_CASE_ProductDev
# 0                    1
# 2                    1
# 3                    0
# 5                    0
# 9                    1
#
# [5 rows x 110 columns]

# %% [markdown]
# # Split the Data into Training and Testing

# %%
# Create our features
X = newdf_.drop(columns=["IS_SUCCESSFUL","Outlier"])
# Create our target
y = newdf_["IS_SUCCESSFUL"]

# %%
X.describe()
# Out:
#             ASK_AMT  AFFILIATION_CompanySponsored  AFFILIATION_Family/Parent  \
# count  2.659400e+04                  26594.000000               26594.000000
# mean   1.194146e+05                      0.518087                   0.000827
# std    1.093656e+07                      0.499682                   0.028751
# min    5.000000e+03                      0.000000                   0.000000
# 25%    5.000000e+03                      0.000000                   0.000000
# 50%    5.000000e+03                      1.000000                   0.000000
# 75%    5.000000e+03                      1.000000                   0.000000
# max    1.736232e+09                      1.000000                   1.000000
#
#        AFFILIATION_Independent  AFFILIATION_National  AFFILIATION_Other  \
# count             26594.000000          26594.000000       26594.000000
# mean                  0.480184              0.000526           0.000113
# std                   0.499617              0.022939           0.010621
# min                   0.000000              0.000000           0.000000
# 25%                   0.000000              0.000000           0.000000
# 50%                   0.000000              0.000000           0.000000
# 75%                   1.000000              0.000000           0.000000
# max                   1.000000              1.000000           1.000000
#
#        AFFILIATION_Regional  ORGANIZATION_Association  \
# count          26594.000000              26594.000000
# mean               0.000263                  0.344476
# std                0.016222                  0.475206
# min                0.000000                  0.000000
# 25%                0.000000                  0.000000
# 50%                0.000000                  0.000000
# 75%                0.000000                  1.000000
# max                1.000000                  1.000000
#
#        ORGANIZATION_Co-operative  ORGANIZATION_Corporation  ...  \
# count               26594.000000              26594.000000  ...
# mean                    0.007746                  0.001090  ...
# std                     0.087672                  0.033005  ...
# min                     0.000000                  0.000000  ...
# 25%                     0.000000                  0.000000  ...
# 50%                     0.000000                  0.000000  ...
# 75%                     0.000000                  0.000000  ...
# max                     1.000000                  1.000000  ...
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# count        26594.000000      26594.000000            26594.000000
# mean             0.000150          0.001918                0.031962
# std              0.012263          0.043751                0.175902
# min              0.000000          0.000000                0.000000
# 25%              0.000000          0.000000                0.000000
# 50%              0.000000          0.000000                0.000000
# 75%              0.000000          0.000000                0.000000
# max              1.000000          1.000000                1.000000
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  USE_CASE_CommunityServ  \
# count     26594.000000       26594.000000            26594.000000
# mean          0.000376           0.000226                0.012898
# std           0.019388           0.015019                0.112835
# min           0.000000           0.000000                0.000000
# 25%           0.000000           0.000000                0.000000
# 50%           0.000000           0.000000                0.000000
# 75%           0.000000           0.000000                0.000000
# max           1.000000           1.000000                1.000000
#
#        USE_CASE_Heathcare  USE_CASE_Other  USE_CASE_Preservation  \
# count        26594.000000    26594.000000           26594.000000
# mean             0.000639        0.000075               0.814657
# std              0.025276        0.008672               0.388583
# min              0.000000        0.000000               0.000000
# 25%              0.000000        0.000000               1.000000
# 50%              0.000000        0.000000               1.000000
# 75%              0.000000        0.000000               1.000000
# max              1.000000        1.000000               1.000000
#
#        USE_CASE_ProductDev
# count         26594.000000
# mean              0.171730
# std               0.377153
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               0.000000
# max               1.000000
#
# [8 rows x 108 columns]

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# 1    14126
# 0    12468
# Name: IS_SUCCESSFUL, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
Counter(y_train)
# Out:
# Counter({1: 10611, 0: 9334})

# %%
from sklearn.preprocessing import StandardScaler
# Creating a StandardScaler instance.
scaler = StandardScaler()
# Fitting the Standard Scaler with the training data.
X_scaler = scaler.fit(X_train)

# Scaling the data.
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
rf_model = BalancedRandomForestClassifier(n_estimators=100, random_state=1) 
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
# Display the confusion matrix: Making predictions using the testing data.
predictions = rf_model.predict(X_test_scaled)
# Calculating the confusion matrix.
rf_cm = confusion_matrix(y_test, predictions)
# Create a DataFrame from the confusion matrix.
rf_cm_df = pd.DataFrame(rf_cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])
rf_cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0         2306          828
# Actual 1          857         2658

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import balanced_accuracy_score
rf_bal_acc_score= round(balanced_accuracy_score(y_test, predictions),2)
accuracy_score_= round(accuracy_score(y_test, predictions),2)
accuracy_score_
# Out:
# 0.75

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
rf_class_rpt=(classification_report_imbalanced(y_test, predictions))
print(rf_class_rpt)
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.73      0.74      0.76      0.73      0.75      0.56      3134
#           1       0.76      0.76      0.74      0.76      0.75      0.56      3515
#
# avg / total       0.75      0.75      0.75      0.75      0.75      0.56      6649

# %%
from sklearn.metrics import recall_score
rf_recall_0=recall_score(y_test, predictions, average="binary",pos_label=0)
rf_recall_1=recall_score(y_test, predictions, average="binary",pos_label=1)

# %%
from sklearn.metrics import precision_score
rf_precision_0=precision_score(y_test, predictions, average="binary",pos_label=0)
rf_precision_1=precision_score(y_test, predictions, average="binary",pos_label=1)

# %%
# Displaying all results
print("Confusion Matrix")
display(rf_cm_df)
print(f"Balanced Accuracy Score : {rf_bal_acc_score}")
print("Classification Report")
print(rf_class_rpt)
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0         2306          828
# Actual 1          857         2658
# Balanced Accuracy Score : 0.75
# Classification Report
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.73      0.74      0.76      0.73      0.75      0.56      3134
#           1       0.76      0.76      0.74      0.76      0.75      0.56      3515
#
# avg / total       0.75      0.75      0.75      0.75      0.75      0.56      6649

# %%
pd.options.display.max_rows = 200
# List the features sorted in descending order by feature importance
importances = rf_model.feature_importances_
sort_orders = sorted(zip(X.columns,importances),reverse=False)
feature_importances = pd.DataFrame(sort_orders,  columns=['Features','importance']).sort_values('importance', ascending=False)
feature_importances
# Out:
#                          Features  importance
# 0    AFFILIATION_CompanySponsored    0.243551
# 2         AFFILIATION_Independent    0.172380
# 18                        ASK_AMT    0.064230
# 99       ORGANIZATION_Association    0.046793
# 102            ORGANIZATION_Trust    0.041468
# 56           CLASSIFICATION_C2100    0.040526
# 13            APPLICATION_TYPE_T5    0.039813
# 6            APPLICATION_TYPE_T10    0.035312
# 9            APPLICATION_TYPE_T19    0.032265
# 12            APPLICATION_TYPE_T4    0.026519
# 11            APPLICATION_TYPE_T3    0.024136
# 55           CLASSIFICATION_C2000    0.021972
# 82           CLASSIFICATION_C7000    0.018026
# 20           CLASSIFICATION_C1000    0.017422
# 14            APPLICATION_TYPE_T6    0.015816
# 21           CLASSIFICATION_C1200    0.015707
# 70           CLASSIFICATION_C3000    0.014331
# 107           USE_CASE_ProductDev    0.014071
# 106         USE_CASE_Preservation    0.013666
# 90                   INCOME_AMT_0    0.010534
# 16            APPLICATION_TYPE_T8    0.007176
# 91              INCOME_AMT_1-9999    0.006679
# 15            APPLICATION_TYPE_T7    0.006388
# 96         INCOME_AMT_25000-99999    0.005434
# 103        USE_CASE_CommunityServ    0.005181
# 83           CLASSIFICATION_C7100    0.005062
# 78           CLASSIFICATION_C5000    0.004983
# 67           CLASSIFICATION_C2700    0.004524
# 93       INCOME_AMT_100000-499999    0.003963
# 69           CLASSIFICATION_C2800    0.003938
# 48           CLASSIFICATION_C1700    0.003774
# 92         INCOME_AMT_10000-24999    0.003471
# 100     ORGANIZATION_Co-operative    0.003014
# 73           CLASSIFICATION_C4000    0.002132
# 60           CLASSIFICATION_C2300    0.001788
# 8            APPLICATION_TYPE_T13    0.001645
# 37           CLASSIFICATION_C1270    0.001325
# 41           CLASSIFICATION_C1300    0.001252
# 95               INCOME_AMT_1M-5M    0.001150
# 39           CLASSIFICATION_C1280    0.001019
# 1       AFFILIATION_Family/Parent    0.001016
# 101      ORGANIZATION_Corporation    0.000924
# 52           CLASSIFICATION_C1800    0.000876
# 28           CLASSIFICATION_C1240    0.000800
# 3            AFFILIATION_National    0.000668
# 80           CLASSIFICATION_C6000    0.000667
# 88           CLASSIFICATION_C8200    0.000632
# 84           CLASSIFICATION_C7120    0.000622
# 85           CLASSIFICATION_C7200    0.000616
# 17            APPLICATION_TYPE_T9    0.000560
# 87           CLASSIFICATION_C8000    0.000546
# 97                INCOME_AMT_50M+    0.000523
# 94             INCOME_AMT_10M-50M    0.000504
# 44           CLASSIFICATION_C1500    0.000452
# 22           CLASSIFICATION_C1230    0.000428
# 71           CLASSIFICATION_C3200    0.000405
# 79           CLASSIFICATION_C5200    0.000389
# 68           CLASSIFICATION_C2710    0.000386
# 81           CLASSIFICATION_C6100    0.000384
# 66           CLASSIFICATION_C2600    0.000364
# 59           CLASSIFICATION_C2190    0.000362
# 35           CLASSIFICATION_C1260    0.000352
# 26           CLASSIFICATION_C1237    0.000336
# 104            USE_CASE_Heathcare    0.000317
# 19              CLASSIFICATION_C0    0.000307
# 7            APPLICATION_TYPE_T12    0.000298
# 43           CLASSIFICATION_C1400    0.000277
# 10            APPLICATION_TYPE_T2    0.000248
# 27           CLASSIFICATION_C1238    0.000245
# 36           CLASSIFICATION_C1267    0.000230
# 98              INCOME_AMT_5M-10M    0.000221
# 49           CLASSIFICATION_C1720    0.000206
# 5            AFFILIATION_Regional    0.000203
# 38           CLASSIFICATION_C1278    0.000201
# 25           CLASSIFICATION_C1236    0.000167
# 62           CLASSIFICATION_C2400    0.000166
# 34           CLASSIFICATION_C1257    0.000162
# 4               AFFILIATION_Other    0.000147
# 86           CLASSIFICATION_C7210    0.000144
# 32           CLASSIFICATION_C1250    0.000137
# 24           CLASSIFICATION_C1235    0.000129
# 53           CLASSIFICATION_C1820    0.000126
# 23           CLASSIFICATION_C1234    0.000108
# 74           CLASSIFICATION_C4100    0.000094
# 105                USE_CASE_Other    0.000085
# 47           CLASSIFICATION_C1600    0.000077
# 30           CLASSIFICATION_C1246    0.000060
# 29           CLASSIFICATION_C1245    0.000044
# 58           CLASSIFICATION_C2170    0.000030
# 31           CLASSIFICATION_C1248    0.000027
# 75           CLASSIFICATION_C4120    0.000025
# 63           CLASSIFICATION_C2500    0.000023
# 45           CLASSIFICATION_C1570    0.000023
# 33           CLASSIFICATION_C1256    0.000022
# 77           CLASSIFICATION_C4500    0.000022
# 40           CLASSIFICATION_C1283    0.000022
# 57           CLASSIFICATION_C2150    0.000022
# 72           CLASSIFICATION_C3700    0.000022
# 42           CLASSIFICATION_C1370    0.000021
# 76           CLASSIFICATION_C4200    0.000020
# 64           CLASSIFICATION_C2561    0.000020
# 65           CLASSIFICATION_C2570    0.000020
# 54           CLASSIFICATION_C1900    0.000018
# 89           CLASSIFICATION_C8210    0.000013
# 61           CLASSIFICATION_C2380    0.000000
# 51           CLASSIFICATION_C1732    0.000000
# 50           CLASSIFICATION_C1728    0.000000
# 46           CLASSIFICATION_C1580    0.000000
